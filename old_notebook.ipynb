# %%
import pandas as pd
import numpy as np
from PIL import Image
import requests
from pathlib import Path
from concurrent.futures import ThreadPoolExecutor, as_completed
import time

# %%
#Data to Load
data_path = 'ZooSpecPhotoDR19_torradeflot.csv'

# %%
# Load and filter the data
df = pd.read_csv(data_path)
filter1 = ((df.modelMagErr_u < 0.5) & (df.modelMagErr_g < 0.05) & (df.modelMagErr_r < 0.05) & (df.modelMagErr_i < 0.05) & (df.modelMagErr_z < 0.05)
           & ((df.p_cs_debiased >= 0.9) | (df.p_el_debiased >= 0.9)))
df_filtered = df[filter1]

# %%
# Function to remove outliers based on quantiles
def remove_outliers(df, low_q = 0.05, high_q = 0.95, cols = [f'modelMag_{f}' for f in "ugriz"]):
    filtered_df = df.copy()
    
    for col in cols:
        low_q_value = filtered_df[col].quantile(low_q)
        high_q_value = filtered_df[col].quantile(high_q)
        filtered_df = filtered_df[(filtered_df[col] >= low_q_value) & (filtered_df[col] <= high_q_value)]
    
    return filtered_df

df_filtered_2 = remove_outliers(df_filtered)

# %%
# Select relevant columns
cols = ['dr7objid', 'ra', 'dec', 'p_el_debiased', 'p_cs_debiased', 'spiral', 'elliptical'] + ['petroR50_r', 'petroR90_r'] + [f'modelMag_{f}' for f in "ugriz"] + [f'extinction_{f}' for f in "ugriz"]
df_filtered_3 = df_filtered_2[cols]

# %%
# Randomly sample 20000 galaxies
n_samples = 20000
sample = df_filtered_3.sample(n_samples, random_state=42)
sample = sample.reset_index(drop=True)
print(sample)
# Out:
#                  dr7objid         ra        dec  p_el_debiased  p_cs_debiased  \
# 0      587725470131224792  126.81580  48.720720          0.000          1.000
# 1      588016892780216485  139.67630  33.748310          0.029          0.932
# 2      588848898835349649  171.87960  -0.982389          0.040          0.960
# 3      588017947199864959  170.77540  40.697470          0.925          0.075
# 4      588018055128154220  250.62700  27.515810          0.068          0.932
# ...                   ...        ...        ...            ...            ...
# 19995  587742629594333315  212.56470  16.515470          0.023          0.940
# 19996  587724240159768697   57.60279  -6.982139          0.008          0.992
# 19997  588013383262994670  129.69650  36.718530          1.000          0.000
# 19998  587732136993161383  170.48320  52.851080          0.023          0.956
# 19999  587736585505996897  226.90250  34.481190          0.000          0.983
#
#        spiral  elliptical  petroR50_r  petroR90_r  modelMag_u  modelMag_g  \
# 0           1           0    4.113575    8.494608    18.47409    16.94238
# 1           1           0    4.199387    8.516226    17.84423    16.61229
# 2           1           0    3.171840    7.115559    18.69905    17.24048
# 3           0           1    2.180486    7.099993    20.11984    18.05107
# 4           1           0    3.369959    7.075009    19.99954    18.13444
# ...       ...         ...         ...         ...         ...         ...
# 19995       1           0    2.762615    6.908694    19.49382    17.88043
# 19996       1           0    2.322508    6.984795    20.11156    18.03956
# 19997       0           1    1.818843    5.649233    20.17397    18.05084
# 19998       1           0    3.748536    9.189739    19.99559    18.16924
# 19999       1           0    5.469940   12.818680    17.94392    16.84068
#
#        modelMag_r  modelMag_i  modelMag_z  extinction_u  extinction_g  \
# 0        16.23789    15.81425    15.53180      0.168785      0.124191
# 1        16.12424    15.84102    15.65725      0.077708      0.057177
# 2        16.48650    16.04601    15.79033      0.121543      0.089430
# 3        16.79846    16.31271    15.98961      0.091304      0.067181
# 4        17.14253    16.55158    16.10788      0.496523      0.365337
# ...           ...         ...         ...           ...           ...
# 19995    16.97387    16.54519    16.23471      0.082711      0.060858
# 19996    16.97488    16.46040    15.97537      0.374625      0.275645
# 19997    16.95883    16.48249    16.09683      0.204100      0.150175
# 19998    17.27638    16.74343    16.35686      0.081330      0.059842
# 19999    16.46594    16.26494    16.13497      0.080474      0.059212
#
#        extinction_r  extinction_i  extinction_z
# 0          0.090073      0.068300      0.048426
# 1          0.041469      0.031445      0.022295
# 2          0.064862      0.049183      0.034871
# 3          0.048725      0.036947      0.026196
# 4          0.264973      0.200921      0.142455
# ...             ...           ...           ...
# 19995      0.044139      0.033469      0.023730
# 19996      0.199921      0.151594      0.107482
# 19997      0.108919      0.082590      0.058557
# 19998      0.043402      0.032911      0.023334
# 19999      0.042945      0.032564      0.023088
#
# [20000 rows x 19 columns]

# %%
# Load your galaxy catalog
# Must have 'ra' and 'dec' columns
df = sample  

# Base output folder
base_out_dir = Path("galaxy_monoc_jpgs")
base_out_dir.mkdir(exist_ok=True)

# HiPS2FITS API base URL
url = "https://alasky.u-strasbg.fr/hips-image-services/hips2fits"
n_images_per_folder = 1000

# %%
# Function to download a single cutout
def download_cutout(index, ra, dec):
    # Determine subfolder
    folder_idx = index // n_images_per_folder
    out_dir = base_out_dir / f"batch_{folder_idx:02d}"
    out_dir.mkdir(exist_ok=True)

    filename = out_dir / f"galaxy_{index}.jpg"
    if filename.exists():  # skip if already downloaded
        return f"Skipped {index}"

    params = {
        "hips": "CDS/P/SDSS9/r",
        "ra": ra,
        "dec": dec,
        "fov": 0.01,     
        "width": 64,
        "height": 64,
        "format": "jpg"
    }

    try:
        response = requests.get(url, params=params, timeout=30)
        if response.status_code == 200:
            with open(filename, "wb") as f:
                f.write(response.content)
            return f"Downloaded {index}"
        else:
            return f"Failed {index}, status {response.status_code}"
    except Exception as e:
        return f"Error {index}: {e}"

# Number of parallel threads
n_threads = 10  # adjust based on your network and server load

# Start parallel downloading
with ThreadPoolExecutor(max_workers=n_threads) as executor:
    futures = [
        executor.submit(download_cutout, i, row["ra"], row["dec"])
        for i, row in df.iterrows()
    ]
    
    for future in as_completed(futures):
        print(future.result())
        time.sleep(0.05)  # small delay to reduce server load
# Out:
# Error 2: HTTPSConnectionPool(host='alasky.u-strasbg.fr', port=443): Max retries exceeded with url: /hips-image-services/hips2fits?hips=CDS%2FP%2FSDSS9%2Fr&ra=171.8796&dec=-0.9823889&fov=0.01&width=64&height=64&format=jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000020B099F5B50>, 'Connection to alasky.u-strasbg.fr timed out. (connect timeout=30)'))
# Error 0: HTTPSConnectionPool(host='alasky.u-strasbg.fr', port=443): Max retries exceeded with url: /hips-image-services/hips2fits?hips=CDS%2FP%2FSDSS9%2Fr&ra=126.8158&dec=48.72072&fov=0.01&width=64&height=64&format=jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000020B0AACE190>, 'Connection to alasky.u-strasbg.fr timed out. (connect timeout=30)'))
# Error 3: HTTPSConnectionPool(host='alasky.u-strasbg.fr', port=443): Max retries exceeded with url: /hips-image-services/hips2fits?hips=CDS%2FP%2FSDSS9%2Fr&ra=170.7754&dec=40.69747&fov=0.01&width=64&height=64&format=jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000020B0884B450>, 'Connection to alasky.u-strasbg.fr timed out. (connect timeout=30)'))
# Error 1: HTTPSConnectionPool(host='alasky.u-strasbg.fr', port=443): Max retries exceeded with url: /hips-image-services/hips2fits?hips=CDS%2FP%2FSDSS9%2Fr&ra=139.6763&dec=33.74831&fov=0.01&width=64&height=64&format=jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000020B098E3A50>, 'Connection to alasky.u-strasbg.fr timed out. (connect timeout=30)'))
# Error 5: HTTPSConnectionPool(host='alasky.u-strasbg.fr', port=443): Max retries exceeded with url: /hips-image-services/hips2fits?hips=CDS%2FP%2FSDSS9%2Fr&ra=240.2053&dec=52.39275&fov=0.01&width=64&height=64&format=jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000020B085F8D90>, 'Connection to alasky.u-strasbg.fr timed out. (connect timeout=30)'))
# Error 4: HTTPSConnectionPool(host='alasky.u-strasbg.fr', port=443): Max retries exceeded with url: /hips-image-services/hips2fits?hips=CDS%2FP%2FSDSS9%2Fr&ra=250.627&dec=27.51581&fov=0.01&width=64&height=64&format=jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000020B08744D50>, 'Connection to alasky.u-strasbg.fr timed out. (connect timeout=30)'))
# Error 7: HTTPSConnectionPool(host='alasky.u-strasbg.fr', port=443): Max retries exceeded with url: /hips-image-services/hips2fits?hips=CDS%2FP%2FSDSS9%2Fr&ra=221.0665&dec=7.323222&fov=0.01&width=64&height=64&format=jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000020B08704410>, 'Connection to alasky.u-strasbg.fr timed out. (connect timeout=30)'))
# Error 6: HTTPSConnectionPool(host='alasky.u-strasbg.fr', port=443): Max retries exceeded with url: /hips-image-services/hips2fits?hips=CDS%2FP%2FSDSS9%2Fr&ra=182.2713&dec=17.01444&fov=0.01&width=64&height=64&format=jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000020B085F8650>, 'Connection to alasky.u-strasbg.fr timed out. (connect timeout=30)'))
# Error 8: HTTPSConnectionPool(host='alasky.u-strasbg.fr', port=443): Max retries exceeded with url: /hips-image-services/hips2fits?hips=CDS%2FP%2FSDSS9%2Fr&ra=204.0635&dec=41.10164&fov=0.01&width=64&height=64&format=jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000020B07517550>, 'Connection to alasky.u-strasbg.fr timed out. (connect timeout=30)'))
# Error 9: HTTPSConnectionPool(host='alasky.u-strasbg.fr', port=443): Max retries exceeded with url: /hips-image-services/hips2fits?hips=CDS%2FP%2FSDSS9%2Fr&ra=256.1053&dec=20.21364&fov=0.01&width=64&height=64&format=jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000020B07517FD0>, 'Connection to alasky.u-strasbg.fr timed out. (connect timeout=30)'))
# Error 10: HTTPSConnectionPool(host='alasky.u-strasbg.fr', port=443): Max retries exceeded with url: /hips-image-services/hips2fits?hips=CDS%2FP%2FSDSS9%2Fr&ra=225.626&dec=23.13358&fov=0.01&width=64&height=64&format=jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000020B7F464F50>, 'Connection to alasky.u-strasbg.fr timed out. (connect timeout=30)'))
# Error 11: HTTPSConnectionPool(host='alasky.u-strasbg.fr', port=443): Max retries exceeded with url: /hips-image-services/hips2fits?hips=CDS%2FP%2FSDSS9%2Fr&ra=227.3359&dec=37.81384&fov=0.01&width=64&height=64&format=jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000020B7F462650>, 'Connection to alasky.u-strasbg.fr timed out. (connect timeout=30)'))
# Error 12: HTTPSConnectionPool(host='alasky.u-strasbg.fr', port=443): Max retries exceeded with url: /hips-image-services/hips2fits?hips=CDS%2FP%2FSDSS9%2Fr&ra=243.9226&dec=52.25317&fov=0.01&width=64&height=64&format=jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000020B7F45FCD0>, 'Connection to alasky.u-strasbg.fr timed out. (connect timeout=30)'))
# Error 13: HTTPSConnectionPool(host='alasky.u-strasbg.fr', port=443): Max retries exceeded with url: /hips-image-services/hips2fits?hips=CDS%2FP%2FSDSS9%2Fr&ra=193.9782&dec=25.34125&fov=0.01&width=64&height=64&format=jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000020B601C2050>, 'Connection to alasky.u-strasbg.fr timed out. (connect timeout=30)'))
# Error 16: HTTPSConnectionPool(host='alasky.u-strasbg.fr', port=443): Max retries exceeded with url: /hips-image-services/hips2fits?hips=CDS%2FP%2FSDSS9%2Fr&ra=215.4807&dec=28.63319&fov=0.01&width=64&height=64&format=jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000020B0BF45E90>, 'Connection to alasky.u-strasbg.fr timed out. (connect timeout=30)'))
# Error 14: HTTPSConnectionPool(host='alasky.u-strasbg.fr', port=443): Max retries exceeded with url: /hips-image-services/hips2fits?hips=CDS%2FP%2FSDSS9%2Fr&ra=341.7528&dec=14.49153&fov=0.01&width=64&height=64&format=jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000020B0BF45450>, 'Connection to alasky.u-strasbg.fr timed out. (connect timeout=30)'))
# Error 15: HTTPSConnectionPool(host='alasky.u-strasbg.fr', port=443): Max retries exceeded with url: /hips-image-services/hips2fits?hips=CDS%2FP%2FSDSS9%2Fr&ra=193.9364&dec=55.31208&fov=0.01&width=64&height=64&format=jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000020B0BF463D0>, 'Connection to alasky.u-strasbg.fr timed out. (connect timeout=30)'))
# Error 17: HTTPSConnectionPool(host='alasky.u-strasbg.fr', port=443): Max retries exceeded with url: /hips-image-services/hips2fits?hips=CDS%2FP%2FSDSS9%2Fr&ra=236.2608&dec=39.34425&fov=0.01&width=64&height=64&format=jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000020B7F45C490>, 'Connection to alasky.u-strasbg.fr timed out. (connect timeout=30)'))
# Error 19: HTTPSConnectionPool(host='alasky.u-strasbg.fr', port=443): Max retries exceeded with url: /hips-image-services/hips2fits?hips=CDS%2FP%2FSDSS9%2Fr&ra=206.7263&dec=37.33667&fov=0.01&width=64&height=64&format=jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000020B0BE9EB50>, 'Connection to alasky.u-strasbg.fr timed out. (connect timeout=30)'))
# Error 18: HTTPSConnectionPool(host='alasky.u-strasbg.fr', port=443): Max retries exceeded with url: /hips-image-services/hips2fits?hips=CDS%2FP%2FSDSS9%2Fr&ra=253.8892&dec=39.58192&fov=0.01&width=64&height=64&format=jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000020B07518250>, 'Connection to alasky.u-strasbg.fr timed out. (connect timeout=30)'))

# %%
# Total number of images to process
read_range = len(sample)
base_out_dir = Path("galaxy_monoc_jpgs")

#List to hold pixel data
pixel_data = []

for idx in range(read_range):
    # Determine subfolder
    folder_idx = idx // n_images_per_folder
    filename = f'{base_out_dir}/batch_{folder_idx:02d}/galaxy_{idx}.jpg'  
    
    # Open image and convert to grayscale (1 channel)
    img_gray = Image.open(filename).convert("L")
    img_arr = np.array(img_gray)

    # Flatten the 2D image array to 1D
    flat_pixels = img_arr.flatten()
    pixel_data.append(flat_pixels)

    # Print progress every 1000 images
    if idx % 1000 == 0:
        print(f"Processed {idx} images")


# Convert list to numpy array
pixel_data = np.array(pixel_data)
pixel_data_normalized = pixel_data.astype(np.float32) / 255.0
print(pixel_data_normalized.shape)
print(pixel_data_normalized)
# Out:
# Processed 0 images
# Processed 1000 images
# Processed 2000 images
# Processed 3000 images
# Processed 4000 images
# Processed 5000 images
# Processed 6000 images
# Processed 7000 images
# Processed 8000 images
# Processed 9000 images
# Processed 10000 images
# Processed 11000 images
# Processed 12000 images
# Processed 13000 images
# Processed 14000 images
# Processed 15000 images
# Processed 16000 images
# Processed 17000 images
# Processed 18000 images
# Processed 19000 images
# (20000, 4096)
# [[0.05098039 0.07450981 0.05490196 ... 0.04705882 0.03921569 0.04705882]
#  [0.03137255 0.02745098 0.02352941 ... 0.00784314 0.01960784 0.03137255]
#  [0.         0.         0.         ... 0.         0.         0.        ]
#  ...
#  [0.01960784 0.02352941 0.02352941 ... 0.02745098 0.01960784 0.02352941]
#  [0.04313726 0.04313726 0.03137255 ... 0.05098039 0.07450981 0.04313726]
#  [0.03921569 0.03137255 0.03921569 ... 0.06666667 0.04705882 0.03529412]]
